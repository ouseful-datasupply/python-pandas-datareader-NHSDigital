# %% [markdown]
# # Usage - python-pandas-datareader-NHSDigital

# %%
#!pip3 install --upgrade --force-reinstall --no-deps python-pandas-datareader-NHSDigital/ 

import pd_datareader_nhs.nhs_digital_ods as ods

# %% [markdown]
# ## Find Datasets From NHS Digital Organisational Data Service
#
# Running any command from the `python-pandas-datareader-NHSDigital` will check whether a "directory" of datasets published by the NHS Organisational Data Service (ODS) is locally available. This information is scraped from the NHS Digital website, cached locally, and may also be persisted in a local SQLiite3 database. For this reason, the first  command run may take some time as the NHS Digital data is downloaded if a persistent database is not available.

# %%
#Find all published datasets (filtered through a whitelist defined in the package)
ss=ods.search(string='')
ss
# Out:
#           Dataset         Date  \
# 0        epraccur  26 May 2017
# 1          egpcur  26 May 2017
# 2        epracmem  26 May 2017
# 3          epcmem  26 May 2017
# 4        epracarc  26 May 2017
# 5          egparc  26 May 2017
# 6        ebranchs  26 May 2017
# 7     epharmacyhq  26 May 2017
# 8     edispensary  26 May 2017
# 9          enurse  26 May 2017
# 10          epcdp  26 May 2017
# 11    eabeydispgp  26 May 2017
# 12          egpam  28 Jul 2017
# 13       egpmemam  28 Jul 2017
# 14        epcdpam  28 Jul 2017
# 15          egpaq  26 May 2017
# 16       egpmemaq  26 May 2017
# 17        epcdpaq  26 May 2017
# 18           eccg  26 May 2017
# 19       eccgsite  26 May 2017
# 20            etr  26 May 2017
# 21            ets  26 May 2017
# 22         etrust  26 May 2017
# 23            ect  26 May 2017
# 24        ectsite  26 May 2017
# 25          ecare  26 May 2017
# 26           wlhb  26 May 2017
# 27       wlhbsite  26 May 2017
# 28           whbs  26 May 2017
# 29          eauth  26 May 2017
# ..            ...          ...
# 33         eother  26 May 2017
# 34           ensa  26 May 2017
# 35           ephp  26 May 2017
# 36       ephpsite  26 May 2017
# 37        enonnhs  26 May 2017
# 38    ecarehomehq  26 May 2017
# 39  ecarehomesite  26 May 2017
# 40  ecarehomesucc  26 May 2017
# 41       eschools  26 May 2017
# 42  educationtype  26 May 2017
# 43          Lauth  26 May 2017
# 44      Lauthsite  26 May 2017
# 45        eprison  26 May 2017
# 46       ejustice  26 May 2017
# 47         eopthq  26 May 2017
# 48       eoptsite  26 May 2017
# 49       egdpprac  25 Nov 2016
# 50           egdp  25 Nov 2016
# 51    egdppracmem  25 Nov 2016
# 52         etreat  26 May 2017
# 53       ehospice  26 May 2017
# 54          eplab  26 May 2017
# 55        educate  26 May 2017
# 56       earchive  26 May 2017
# 57           succ  26 May 2017
# 58        succarc  26 May 2017
# 59        econcur  28 Jul 2017
# 60       edconcur  28 Jul 2017
# 61        wconcur  26 May 2017
# 62        default  26 May 2017
#
#                                                 Label     Period  \
# 0                                        GP Practices  Quarterly
# 1                                    GP Practitioners  Quarterly
# 2                                 GPs by GP Practices  Quarterly
# 3                      GP Practices linked to CCG/LHG  Quarterly
# 4                               Archived GP Practices  Quarterly
# 5                           Archived GP Practitioners  Quarterly
# 6                                    Branch Surgeries  Quarterly
# 7                 Pharmacy Headquarters Organisations  Quarterly
# 8                                        Dispensaries  Quarterly
# 9                         Nurse Presribers in England  Quarterly
# 10     Private Controlled Drug Prescribers in England  Quarterly
# 11                    Abeyance and Dispersal GP Codes  Quarterly
# 12           GP Practitioners and Practice amendments    Monthly
# 13  GPs by GP Practices and GP Practices linked to...    Monthly
# 14  Private Controlled Drug Prescribers in England...    Monthly
# 15           GP Practitioners and Practice amendments  Quarterly
# 16  GPs by GP Practices and GP Practices linked to...  Quarterly
# 17  Private Controlled Drug Prescribers in England...  Quarterly
# 18                      Clinical Commissioning Groups  Quarterly
# 19                 Clinical Commissioning Group sites  Quarterly
# 20                                         NHS Trusts  Quarterly
# 21                                    NHS Trust sites  Quarterly
# 22                               NHS Trusts and sites  Quarterly
# 23                                        Care Trusts  Quarterly
# 24                                   Care Trust sites  Quarterly
# 25                              Care Trusts and sites  Quarterly
# 26                          Welsh Local Health Boards  Quarterly
# 27                     Welsh Local Health Board sites  Quarterly
# 28                Welsh Local Health Boards and sites  Quarterly
# 29  NHS England Commissioning and Government Offic...  Quarterly
# ..                                                ...        ...
# 33                         Executive Agency Programme  Quarterly
# 34           NHS Support Agencies and Shared Services  Quarterly
# 35            Independent Sector Healthcare Providers  Quarterly
# 36      Independent Sector Healthcare Providers sites  Quarterly
# 37     Non- NHS Organisations - Independent Providers  Quarterly
# 38                             Care Home Headquarters  Quarterly
# 39                                    Care Home sites  Quarterly
# 40      Closed Care Home Organisation with successors  Quarterly
# 41                                 Schools in England  Quarterly
# 42                   Lookup Education type identifier  Quarterly
# 43                              Local Authority codes  Quarterly
# 44                              Local Authority sites  Quarterly
# 45                       Prisons in England and Wales  Quarterly
# 46                   Health and Justice Organisations  Quarterly
# 47                               Optical Headquarters  Quarterly
# 48                                      Optical sites  Quarterly
# 49                           General Dental Practices  Quarterly
# 50                       General Dental Practitioners  Quarterly
# 51                 General Dental Practice membership  Quarterly
# 52                                  Treatment Centres  Quarterly
# 53                                           Hospices  Quarterly
# 54                             Pathology Laboratories  Quarterly
# 55                           Education Establishments  Quarterly
# 56                      Archived Closed Organisations  Quarterly
# 57                            Successor Organisations  Quarterly
# 58                   Archived Successor Organisations  Quarterly
# 59                       English Hospital Consultants    Monthly
# 60                         English Dental Consultants    Monthly
# 61                         Welsh Hospital Consultants  Quarterly
# 62                                      Default codes  Quarterly
#
#                   Type                                                URL
# 0              gp-data  https://digital.nhs.uk/media/372/epraccur/zip/...
# 1              gp-data  https://digital.nhs.uk/media/370/egpcur/zip/eg...
# 2              gp-data  https://digital.nhs.uk/media/379/epracmem/zip/...
# 3              gp-data  https://digital.nhs.uk/media/378/epcmem/zip/ep...
# 4              gp-data  https://digital.nhs.uk/media/376/epracarc/zip/...
# 5              gp-data  https://digital.nhs.uk/media/374/egparc/zip/eg...
# 6              gp-data  https://digital.nhs.uk/media/393/ebranchs/zip/...
# 7              gp-data  https://digital.nhs.uk/media/391/epharmacyhq/z...
# 8              gp-data  https://digital.nhs.uk/media/390/edispensary/z...
# 9              gp-data  https://digital.nhs.uk/media/388/enurse/zip/en...
# 10             gp-data   https://digital.nhs.uk/media/387/epcdp/zip/epcdp
# 11             gp-data  https://digital.nhs.uk/media/385/eabeydispgp/z...
# 12             gp-data  https://digital.nhs.uk/media/1254/egpam/zip/egpam
# 13             gp-data  https://digital.nhs.uk/media/479/egpmemam/zip/...
# 14             gp-data  https://digital.nhs.uk/media/1256/epcdpam/zip/...
# 15             gp-data  https://digital.nhs.uk/media/1360/egpaq/zip/egpaq
# 16             gp-data  https://digital.nhs.uk/media/1361/egpmemaq/zip...
# 17             gp-data  https://digital.nhs.uk/media/1362/epcdpaq/zip/...
# 18           other-nhs     https://digital.nhs.uk/media/354/eccg/zip/eccg
# 19           other-nhs  https://digital.nhs.uk/media/353/eccgsite/zip/...
# 20           other-nhs       https://digital.nhs.uk/media/352/etr/zip/etr
# 21           other-nhs       https://digital.nhs.uk/media/351/ets/zip/ets
# 22           other-nhs  https://digital.nhs.uk/media/350/etrust/zip/et...
# 23           other-nhs       https://digital.nhs.uk/media/349/ect/zip/ect
# 24           other-nhs  https://digital.nhs.uk/media/348/ectsite/zip/e...
# 25           other-nhs   https://digital.nhs.uk/media/347/ecare/zip/ecare
# 26           other-nhs     https://digital.nhs.uk/media/346/wlhb/zip/wlhb
# 27           other-nhs  https://digital.nhs.uk/media/345/wlhbsite/zip/...
# 28           other-nhs     https://digital.nhs.uk/media/344/whbs/zip/whbs
# 29  health-authorities   https://digital.nhs.uk/media/332/eauth/zip/eauth
# ..                 ...                                                ...
# 33  health-authorities  https://digital.nhs.uk/media/340/eother/zip/eo...
# 34  health-authorities     https://digital.nhs.uk/media/339/ensa/zip/ensa
# 35             non-nhs     https://digital.nhs.uk/media/414/ephp/zip/ephp
# 36             non-nhs  https://digital.nhs.uk/media/412/ephpsite/zip/...
# 37             non-nhs  https://digital.nhs.uk/media/411/enonnhs/zip/e...
# 38             non-nhs  https://digital.nhs.uk/media/409/ecarehomehq/z...
# 39             non-nhs  https://digital.nhs.uk/media/408/ecarehomesite...
# 40             non-nhs  https://digital.nhs.uk/media/407/ecarehomesucc...
# 41             non-nhs  https://digital.nhs.uk/media/406/eschools/zip/...
# 42             non-nhs  https://digital.nhs.uk/media/404/educationtype...
# 43             non-nhs   https://digital.nhs.uk/media/403/Lauth/zip/Lauth
# 44             non-nhs  https://digital.nhs.uk/media/402/Lauthsite/zip...
# 45             non-nhs  https://digital.nhs.uk/media/401/eprison/zip/e...
# 46             non-nhs  https://digital.nhs.uk/media/400/ejustice/zip/...
# 47       miscellaneous  https://digital.nhs.uk/media/468/eopthq/zip/eo...
# 48       miscellaneous  https://digital.nhs.uk/media/467/eoptsite/zip/...
# 49       miscellaneous  https://digital.nhs.uk/media/466/egdpprac/zip/...
# 50       miscellaneous     https://digital.nhs.uk/media/464/egdp/zip/egdp
# 51       miscellaneous  https://digital.nhs.uk/media/463/egdppracmem/z...
# 52       miscellaneous  https://digital.nhs.uk/media/462/etreat/zip/et...
# 53       miscellaneous  https://digital.nhs.uk/media/461/ehospice/zip/...
# 54       miscellaneous   https://digital.nhs.uk/media/460/eplab/zip/eplab
# 55       miscellaneous  https://digital.nhs.uk/media/458/educate/zip/e...
# 56       miscellaneous  https://digital.nhs.uk/media/457/earchive/zip/...
# 57       miscellaneous     https://digital.nhs.uk/media/455/succ/zip/succ
# 58       miscellaneous  https://digital.nhs.uk/media/453/succarc/zip/s...
# 59       miscellaneous  https://digital.nhs.uk/media/450/econcur/zip/e...
# 60       miscellaneous  https://digital.nhs.uk/media/449/edconcur/zip/...
# 61       miscellaneous  https://digital.nhs.uk/media/448/wconcur/zip/w...
# 62       miscellaneous  https://digital.nhs.uk/media/447/default/zip/d...
#
# [63 rows x 6 columns]

# %%
#View whitelist of packages that have dataframe mappings defined
ods.dataset_codes
# Out:
# ['epraccur',
#  'etrust',
#  'eccg',
#  'eccgsite',
#  'epcmem',
#  'epracmem',
#  'egdpprac',
#  'egpcur',
#  'egparc',
#  'epracarc',
#  'ehospice',
#  'epharmacyhq',
#  'edispensary',
#  'enurse',
#  'epcdp',
#  'eabeydispgp',
#  'ecarehomehq',
#  'ecarehomesite',
#  'ecarehomesucc',
#  'ephp',
#  'ephpsite',
#  'enonnhs',
#  'eprison',
#  'eschools',
#  'ejustice',
#  'ecare']

# %%
#The mappings are provided as JSON data that define things such as column headings and code mappings
ods.jdata['egpcur']
# Out:
# {'codes': {'Organisation Sub-Type Code': {'O': 'Other GP in practice (not Principal/Senior GP)',
#    'P': 'Principal/Senior GP at practice'},
#   'Status Code': {'A': 'Active',
#    'B': 'Retired',
#    'C': 'Closed',
#    'P': 'Proposed'}},
#  'cols': ['Organisation Code',
#   'Name',
#   'National Grouping',
#   'High Level Health Geography',
#   'Address Line 1',
#   'Address Line 2',
#   'Address Line 3',
#   'Address Line 4',
#   'Address Line 5',
#   'Postcode',
#   'Open Date',
#   'Close Date',
#   'Status Code',
#   'Organisation Sub-Type Code',
#   'Parent Organisation Code',
#   'Join Parent Date',
#   'Left Parent Date',
#   'Contact Telephone Number',
#   'Null',
#   'Null',
#   'Null',
#   'Amended Record Indicator',
#   'Null',
#   'Current Care Organisation',
#   'Null',
#   'Null',
#   'Null'],
#  'dates': 'auto',
#  'index': 'auto'}

# %%
#Search by ODS dataset type - searches are partial match
ods.search(string='Prison', field='Label')
# Out:
#     Dataset         Date                         Label     Period     Type  \
# 45  eprison  26 May 2017  Prisons in England and Wales  Quarterly  non-nhs
#
#                                                   URL
# 45  https://digital.nhs.uk/media/401/eprison/zip/e...

# %%
#Case sensitive search of datasets by field
len(ods.search('gp-data', field='Type')), len(ods.search(string='gp', field='Label', case=True))
# Out:
# (18, 0)

# %%
#Search datasets by field
ods.search(string='health-authorities', field='Type')
# Out:
#      Dataset         Date                                              Label  \
# 29     eauth  26 May 2017  NHS England Commissioning and Government Offic...
# 30     espha  26 May 2017                         Special Health Authorities
# 31      ecsu  26 May 2017                        Commissioning Support Units
# 32  ecsusite  26 May 2017                  Commissioning Support Units sites
# 33    eother  26 May 2017                         Executive Agency Programme
# 34      ensa  26 May 2017           NHS Support Agencies and Shared Services
#
#        Period                Type  \
# 29  Quarterly  health-authorities
# 30  Quarterly  health-authorities
# 31  Quarterly  health-authorities
# 32  Quarterly  health-authorities
# 33  Quarterly  health-authorities
# 34  Quarterly  health-authorities
#
#                                                   URL
# 29   https://digital.nhs.uk/media/332/eauth/zip/eauth
# 30   https://digital.nhs.uk/media/343/espha/zip/espha
# 31     https://digital.nhs.uk/media/342/ecsu/zip/ecsu
# 32  https://digital.nhs.uk/media/341/ecsusite/zip/...
# 33  https://digital.nhs.uk/media/340/eother/zip/eo...
# 34     https://digital.nhs.uk/media/339/ensa/zip/ensa

# %% [markdown]
# ## Download Datasets

# %% [markdown]
# *Available datasets* are ones that have been downloaded and cached locally.

# %%
ods.availableDatasets()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
epraccur_df = ods.download('epraccur')
epraccur_df.head()
# Out:
#   Organisation Code                        Name National Grouping  \
# 0            A81001         THE DENSHAM SURGERY               Y54
# 1            A81002  QUEENS PARK MEDICAL CENTRE               Y54
# 2            A81003   VICTORIA MEDICAL PRACTICE               Y54
# 3            A81004      WOODLANDS ROAD SURGERY               Y54
# 4            A81005          SPRINGWOOD SURGERY               Y54
#
#   High Level Health Geography           Address Line 1 Address Line 2  \
# 0                         Q74        THE HEALTH CENTRE  LAWSON STREET
# 1                         Q74  QUEENS PARK MEDICAL CTR  FARRER STREET
# 2                         Q74        THE HEALTH CENTRE  VICTORIA ROAD
# 3                         Q74         6 WOODLANDS ROAD            NaN
# 4                         Q74       SPRINGWOOD SURGERY   RECTORY LANE
#
#      Address Line 3 Address Line 4 Address Line 5  Postcode  \
# 0  STOCKTON-ON-TEES      CLEVELAND            NaN  TS18 1HU
# 1  STOCKTON ON TEES      CLEVELAND            NaN  TS18 2AW
# 2        HARTLEPOOL      CLEVELAND            NaN  TS26 8DB
# 3     MIDDLESBROUGH      CLEVELAND            NaN   TS1 3BE
# 4       GUISBOROUGH            NaN            NaN  TS14 7DJ
#
#              ...            Commissioner Join Provider/Purchaser Date  \
# 0            ...                     00K                   2013-04-01
# 1            ...                     00K                   2013-04-01
# 2            ...                     00K                   2013-04-01
# 3            ...                     00M                   2013-04-01
# 4            ...                     00M                   2013-04-01
#
#   Left Provider/Purchaser Date Contact Telephone Number  \
# 0                          NaT             01642 672351
# 1                          NaT             01642 679681
# 2                          NaT             01429 272945
# 3                          NaT             01642 247982
# 4                          NaT             01287 619611
#
#   Amended Record Indicator Provider/Purchaser Prescribing Setting  \
# 0                        0                00K                   4
# 1                        0                00K                   4
# 2                        0                00K                   4
# 3                        0                00M                   4
# 4                        0                00M                   4
#
#   Status Code Value                Organisation Sub-Type Code Value  \
# 0            Active  Allocated to a Provider/Purchaser Organisation
# 1            Active  Allocated to a Provider/Purchaser Organisation
# 2           Dormant  Allocated to a Provider/Purchaser Organisation
# 3            Active  Allocated to a Provider/Purchaser Organisation
# 4            Active  Allocated to a Provider/Purchaser Organisation
#
#   Prescribing Setting Value
# 0               GP Practice
# 1               GP Practice
# 2               GP Practice
# 3               GP Practice
# 4               GP Practice
#
# [5 rows x 24 columns]

# %%
#We can check to see what datasets have been downloaded and persisted in SQLite storage
ods.availableDatasets()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#Or check to see what files are avialble in the local, in-memory cach
ods.availableDatasets(typ='cached')
# Out:
#     Dataset         Date         Label     Period     Type  \
# 0  epraccur  26 May 2017  GP Practices  Quarterly  gp-data
#
#                                                  URL
# 0  https://digital.nhs.uk/media/372/epraccur/zip/...

# %%
#We can download all the datasets in an ODS group
dd=ods.download(datatype='other-nhs')
ods.availableDatasets(typ='cached')
# Out:
#      Dataset         Date                               Label     Period  \
# 0   epraccur  26 May 2017                        GP Practices  Quarterly
# 18      eccg  26 May 2017       Clinical Commissioning Groups  Quarterly
# 19  eccgsite  26 May 2017  Clinical Commissioning Group sites  Quarterly
# 22    etrust  26 May 2017                NHS Trusts and sites  Quarterly
# 25     ecare  26 May 2017               Care Trusts and sites  Quarterly
#
#          Type                                                URL
# 0     gp-data  https://digital.nhs.uk/media/372/epraccur/zip/...
# 18  other-nhs     https://digital.nhs.uk/media/354/eccg/zip/eccg
# 19  other-nhs  https://digital.nhs.uk/media/353/eccgsite/zip/...
# 22  other-nhs  https://digital.nhs.uk/media/350/etrust/zip/et...
# 25  other-nhs   https://digital.nhs.uk/media/347/ecare/zip/ecare

# %%
#We can also download a list of names datsets
dd=ods.download(['eprison','eschools'])
ods.availableDatasets(typ='cached')
# Out:
#      Dataset         Date                               Label     Period  \
# 0   epraccur  26 May 2017                        GP Practices  Quarterly
# 18      eccg  26 May 2017       Clinical Commissioning Groups  Quarterly
# 19  eccgsite  26 May 2017  Clinical Commissioning Group sites  Quarterly
# 22    etrust  26 May 2017                NHS Trusts and sites  Quarterly
# 25     ecare  26 May 2017               Care Trusts and sites  Quarterly
# 41  eschools  26 May 2017                  Schools in England  Quarterly
# 45   eprison  26 May 2017        Prisons in England and Wales  Quarterly
#
#          Type                                                URL
# 0     gp-data  https://digital.nhs.uk/media/372/epraccur/zip/...
# 18  other-nhs     https://digital.nhs.uk/media/354/eccg/zip/eccg
# 19  other-nhs  https://digital.nhs.uk/media/353/eccgsite/zip/...
# 22  other-nhs  https://digital.nhs.uk/media/350/etrust/zip/et...
# 25  other-nhs   https://digital.nhs.uk/media/347/ecare/zip/ecare
# 41    non-nhs  https://digital.nhs.uk/media/406/eschools/zip/...
# 45    non-nhs  https://digital.nhs.uk/media/401/eprison/zip/e...

# %%
#If we try to download files for which there is no mapping, we get a warning
dd=ods.download(['eother','eauth'])
ods.availableDatasets(typ='cached')
# Out:
# /usr/local/lib/python3.6/site-packages/pd_datareader_nhs/nhs_digital_ods.py:80: UserWarning: Non-standard dataset codes: eauth, eother
#   'codes: %s' % tmp, UserWarning)
#      Dataset         Date                               Label     Period  \
# 0   epraccur  26 May 2017                        GP Practices  Quarterly
# 18      eccg  26 May 2017       Clinical Commissioning Groups  Quarterly
# 19  eccgsite  26 May 2017  Clinical Commissioning Group sites  Quarterly
# 22    etrust  26 May 2017                NHS Trusts and sites  Quarterly
# 25     ecare  26 May 2017               Care Trusts and sites  Quarterly
# 41  eschools  26 May 2017                  Schools in England  Quarterly
# 45   eprison  26 May 2017        Prisons in England and Wales  Quarterly
#
#          Type                                                URL
# 0     gp-data  https://digital.nhs.uk/media/372/epraccur/zip/...
# 18  other-nhs     https://digital.nhs.uk/media/354/eccg/zip/eccg
# 19  other-nhs  https://digital.nhs.uk/media/353/eccgsite/zip/...
# 22  other-nhs  https://digital.nhs.uk/media/350/etrust/zip/et...
# 25  other-nhs   https://digital.nhs.uk/media/347/ecare/zip/ecare
# 41    non-nhs  https://digital.nhs.uk/media/406/eschools/zip/...
# 45    non-nhs  https://digital.nhs.uk/media/401/eprison/zip/e...

# %%
#Display a downloaded dataset - we will use cached data if available
ods.download('eprison').head()
# Out:
#   Organisation Code                Name    Address Line 1 Address Line 2  \
# 0             YDE01  HMP NORTHUMBERLAND        ACKLINGTON            NaN
# 1             YDE02   HMP ISLE OF WIGHT     CLISSOLD ROAD            NaN
# 2             YDE03       HMP ALTCOURSE       HIGHER LANE     FAZAKERLEY
# 3             YDE05         HMP BEDFORD  ST. LOYES STREET            NaN
# 4             YDE06        HMP BELMARSH   1 BELMARSH ROAD    WESTERN WAY
#
#   Address Line 3 Address Line 4  Address Line 5  Postcode  Open Date  \
# 0            NaN        MORPETH  NORTHUMBERLAND  NE65 9XG 2003-04-01
# 1            NaN        NEWPORT   ISLE OF WIGHT  PO30 5RS 2003-04-01
# 2            NaN      LIVERPOOL      MERSEYSIDE    L9 7LH 2003-04-01
# 3            NaN        BEDFORD    BEDFORDSHIRE  MK40 1HG 2003-04-01
# 4     THAMESMEAD         LONDON  GREATER LONDON  SE28 0EB 2003-04-01
#
#   Close Date  Contact Telephone Number  Amended Record Indicator
# 0        NaT                       NaN                         0
# 1        NaT                       NaN                         0
# 2        NaT                       NaN                         0
# 3        NaT                       NaN                         0
# 4        NaT                       NaN                         0

# %%
#If we download multiple datsets in one go, we get a dict of dataframes
dd=ods.download(['eprison','eschools'])
dd['eschools'].head()
# Out:
#   Organisation Code                                       Name  \
# 0          EE100000  SIR JOHN CASS'S FOUNDATION PRIMARY SCHOOL
# 1          EE100001            CITY OF LONDON SCHOOL FOR GIRLS
# 2          EE100002                 ST PAUL'S CATHEDRAL SCHOOL
# 3          EE100003                      CITY OF LONDON SCHOOL
# 4          EE100005                        THOMAS CORAM CENTRE
#
#   National Grouping High Level Health Geography          Address Line 1  \
# 0               Y56                         Q71      ST JAMES'S PASSAGE
# 1               Y56                         Q71       ST GILES' TERRACE
# 2               Y56                         Q71            2 NEW CHANGE
# 3               Y56                         Q71   QUEEN VICTORIA STREET
# 4               Y56                         Q71  49 MECKLENBURGH SQUARE
#
#   Address Line 2 Address Line 3 Address Line 4 Address Line 5  Postcode  \
# 0   DUKE'S PLACE            NaN         LONDON            NaN  EC3A 5DE
# 1       BARBICAN            NaN         LONDON            NaN  EC2Y 8BB
# 2            NaN            NaN         LONDON            NaN  EC4M 9AD
# 3            NaN            NaN         LONDON            NaN  EC4V 3AL
# 4            NaN            NaN         LONDON            NaN  WC1N 2NY
#
#    Open Date Close Date  Local Authority  Contact Telephone Number  \
# 0 1900-01-01        NaT              714              2.072831e+09
# 1 1920-01-01        NaT              714              2.078476e+09
# 2 1939-01-01        NaT              714              2.072485e+09
# 3 1919-01-01        NaT              714              2.074890e+09
# 4 1900-01-01        NaT              702              2.075200e+09
#
#    Amended Record Indicator Current Care Organisation  Type of Establishment  \
# 0                         0                       07T                      2
# 1                         0                       07T                     11
# 2                         0                       07T                     11
# 3                         0                       07T                     11
# 4                         0                       07R                     15
#
#   Type of Establishment Value
# 0      VOLUNTARY AIDED SCHOOL
# 1    OTHER INDEPENDENT SCHOOL
# 2    OTHER INDEPENDENT SCHOOL
# 3    OTHER INDEPENDENT SCHOOL
# 4           LA NURSERY SCHOOL

# %% [markdown]
# ## Persistent Database
#
# We can initialise the package to use a persistent, named database.
#
# If there is any cached data, add that to the database. If there is no cached data, and no netwrok connection, and a database is specified, we use that.
#
# If there is a network connection, if the date field in the list of datatables is different to the persisted item in the database, the database copy will be uploaded with a new downloaded version if the datastet is "downloaded".

# %%
# !rm nhs_ods_test1.sqlite
ods.init(sqlite3db='nhs_ods_test1.sqlite')
# Out:
# rm: nhs_ods_test1.sqlite: No such file or directory
# Setting up a new dataset_date table...
# /usr/local/lib/python3.6/site-packages/pandas/core/generic.py:1362: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   chunksize=chunksize, dtype=dtype)

# %%
ods.availableDatasets()
# Out:
#     Dataset         Date
# 0  epraccur  26 May 2017
# 1    etrust  26 May 2017
# 2      eccg  26 May 2017
# 3  eccgsite  26 May 2017
# 4   eprison  26 May 2017
# 5  eschools  26 May 2017
# 6     ecare  26 May 2017

# %%
#We can also update the database to grab all the whitelisted datasets
ods.updatedb()
ods.availableDatasets()
# Out:
# /usr/local/lib/python3.6/site-packages/pandas/core/generic.py:1362: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   chunksize=chunksize, dtype=dtype)
#           Dataset         Date
# 0        epraccur  26 May 2017
# 1          etrust  26 May 2017
# 2            eccg  26 May 2017
# 3        eccgsite  26 May 2017
# 4          epcmem  26 May 2017
# 5        epracmem  26 May 2017
# 6        egdpprac  25 Nov 2016
# 7          egpcur  26 May 2017
# 8          egparc  26 May 2017
# 9        epracarc  26 May 2017
# 10       ehospice  26 May 2017
# 11    epharmacyhq  26 May 2017
# 12    edispensary  26 May 2017
# 13         enurse  26 May 2017
# 14          epcdp  26 May 2017
# 15    eabeydispgp  26 May 2017
# 16    ecarehomehq  26 May 2017
# 17  ecarehomesite  26 May 2017
# 18  ecarehomesucc  26 May 2017
# 19           ephp  26 May 2017
# 20       ephpsite  26 May 2017
# 21        enonnhs  26 May 2017
# 22        eprison  26 May 2017
# 23       eschools  26 May 2017
# 24       ejustice  26 May 2017
# 25          ecare  26 May 2017
